# %%
import pandas as pd
import numpy as np
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.5.2

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot  #online mode is paid and hosted in their server

# %%
init_notebook_mode(connected=True)  #connect Javascript to notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline() #to make cufflinks in offline mode
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Data
df = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])
df
# Out:
#            A         B         C         D
# 0   1.308454  1.097781  0.344687  0.658625
# 1  -0.620727 -0.745799  0.141273  0.481360
# 2  -0.066542  1.809156  1.646229 -1.290387
# 3  -0.741059 -0.553968  1.956956  0.438027
# 4  -0.184665 -1.318783 -0.873275 -0.588396
# 5   0.189823  0.063243  1.383222  0.450836
# 6  -0.942890 -0.549844  0.544586  1.842458
# 7   0.210143 -0.372491 -0.143923 -0.130622
# 8   1.630510  1.676116 -0.566924  0.003600
# 9  -0.361201 -1.744441  0.315345 -0.962490
# 10  1.564769  0.534228  0.947821 -0.284725
# 11 -0.317048 -0.363382  0.674324 -0.956966
# 12  1.169108  0.745747  0.341793 -0.878622
# 13  0.747389  0.436383  2.085663 -0.045405
# 14 -2.062903  0.513516 -0.264159  1.253350
# 15  0.152009  0.405525  0.613116 -1.735556
# 16  1.482794  1.182939  0.183713 -0.261935
# 17 -0.041760  1.685722 -0.089183 -0.365776
# 18  0.185104  0.220533 -0.383680 -0.615669
# 19  1.429998  1.538934 -0.875089  1.931731
# 20 -0.940635 -0.221030 -0.678808  0.889471
# ...

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'values':[32,43,50]})
df2
# Out:
#   Category  values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="6c24e871-e1aa-48c7-83dd-8a2ed42b5360" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6c24e871-e1aa-48c7-83dd-8a2ed42b5360")) {
#                     Plotly.newPlot(
#                         '6c24e871-e1aa-48c7-83dd-8a2ed42b5360',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers') #mode = markers will suppress the lines that iplot creates by default
# Out:
# <div>
#
#
#             <div id="5a267060-07a4-4329-8fc2-e23c4f12b084" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5a267060-07a4-4329-8fc2-e23c4f12b084")) {
#                     Plotly.newPlot(
#                         '5a267060-07a4-4329-8fc2-e23c4f12b084',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='values')
# Out:
# <div>
#
#
#             <div id="f3c35bed-cd5c-43e0-8835-973f4a2f92aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f3c35bed-cd5c-43e0-8835-973f4a2f92aa")) {
#                     Plotly.newPlot(
#                         'f3c35bed-cd5c-43e0-8835-973f4a2f92aa',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.sum().iplot('bar')
# Out:
# <div>
#
#
#             <div id="8d900136-61a7-4bdf-b0b1-928f79d3e0c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8d900136-61a7-4bdf-b0b1-928f79d3e0c6")) {
#                     Plotly.newPlot(
#                         '8d900136-61a7-4bdf-b0b1-928f79d3e0c6',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [3.4082124529846394, 1.2559268918561968, 15.103527610250495, -8.520849555137236]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="72c31298-f9cb-4f88-957d-007fc1cf70ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("72c31298-f9cb-4f88-957d-007fc1cf70ec")) {
#                     Plotly.newPlot(
#                         '72c31298-f9cb-4f88-957d-007fc1cf70ec',
# ...

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,40,50],'z':[100,200,300,400,500]})

# %%
df3.iplot('surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="ad00f3ac-7fff-4ade-91e8-d6dae2c9e8c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ad00f3ac-7fff-4ade-91e8-d6dae2c9e8c3")) {
#                     Plotly.newPlot(
#                         'ad00f3ac-7fff-4ade-91e8-d6dae2c9e8c3',
# ...

# %%
df['A'].iplot('hist',bins=30)
# Out:
# <div>
#
#
#             <div id="9e5129c7-7193-4684-ac1c-1d0760220506" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9e5129c7-7193-4684-ac1c-1d0760220506")) {
#                     Plotly.newPlot(
#                         '9e5129c7-7193-4684-ac1c-1d0760220506',
# ...

# %%
df[['A','B']].iplot('spread')
# Out:
# <div>
#
#
#             <div id="d62dcc2f-b2b7-40fc-9f37-cc6e2f87a131" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d62dcc2f-b2b7-40fc-9f37-cc6e2f87a131")) {
#                     Plotly.newPlot(
#                         'd62dcc2f-b2b7-40fc-9f37-cc6e2f87a131',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="1a072764-2246-4227-aba3-f3731a978bc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1a072764-2246-4227-aba3-f3731a978bc7")) {
#                     Plotly.newPlot(
#                         '1a072764-2246-4227-aba3-f3731a978bc7',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="f08e7bb6-560a-493f-ad88-34209fbd323d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f08e7bb6-560a-493f-ad88-34209fbd323d")) {
#                     Plotly.newPlot(
#                         'f08e7bb6-560a-493f-ad88-34209fbd323d',
# ...
